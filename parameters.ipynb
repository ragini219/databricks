# %% [markdown]
# # Input to the dynamic data load notebook

# %%
datasets = [
    {
        "file_name" : "orders"
    },
    {
        "file_name" : "customers"
    },
    {
        "file_name" : "products"
    }
]

# %%
dbutils.jobs.taskValues.set("output_datasets", datasets)
